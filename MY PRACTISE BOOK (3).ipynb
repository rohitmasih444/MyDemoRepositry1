# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\sainik\Desktop\comma sapreted.csv")
# Out:
#      Name      Batch RollNum   Address
# 0   Allen      py-09      12     Delhi
# 1   Solly      py-98      32    Rampur
# 2  Sachin      py-21      24  Haldwani
# 3   Rohit  Not py-01      43      Bhot
# 4  Adsdas       fsdf  dsdgfs      adfs

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sainik'

# %%
pd.read_csv(r"MyFourthData11.csv")
# Out:
#      Name      Batch  RollNum   Address
# 0   Allen      py-09       12     Delhi
# 1   Solly      py-98       32    Rampur
# 2  Sachin      py-21       24  Haldwani
# 3   Rohit  Not py-01       43      Bhot
# 4   Shera  pyhton-01       11   Pataudi
# 5    Anil      py-44       44    Ashram
# 6  Deepji   Programm       55  Hydrabad

# %%
pd.read_excel(r"C:\Users\sainik\Desktop\April Month Report.xls")
# Out:
#                   Unnamed: 0            Unnamed: 1       Unnamed: 2  \
# 0        Sales Record Number          Order Number   Buyer Username
# 1                        NaN                   NaN              NaN
# 2                       8068        18-08570-62102     piscesyooo_1
# 3                       8067        11-08571-88355     13godess.feb
# 4                       8066        27-08559-03533        ye_590480
# 5                       8065        03-08565-17313  phi_pp_6jwkqij9
# 6                       8064        06-08564-51193  phi_pp_6jwkqij9
# 7                       8063        21-08560-05651  phi_pp_6jwkqij9
# 8                       8062        03-08561-33464  phi_pp_6jwkqij9
# 9                       8061        05-08560-02304       cheney1106
# 10                      8060        18-08566-08023       georo-5942
# 11                      8059        16-08548-42622        ye_590480
# 12                      8058        19-08546-33226         leekonti
# ...

# %%
pd.read_csv(r'C:\Users\sainik\Desktop\TSVFile.txt',sep='\t')
# Out:
#      Name      Batch RollNum   Address
# 0   Allen      py-09      12     Delhi
# 1   Solly      py-98      32    Rampur
# 2  Sachin      py-21      24  Haldwani
# 3   Rohit  Not py-01      43      Bhot
# 4  Adsdas       fsdf  dsdgfs      adfs

# %%
pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/dataset1/master/Skyserver.csv")
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598370   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv")
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/Advertising.csv')
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
pd.read_excel(r"C:\Users\sainik\Downloads\train_agriculture (1).xlsx")
# Out:
#              ID  Estimated_Insects_Count  Crop_Type  Soil_Type  \
# 0     F00000001                      188          1          0
# 1     F00000003                      209          1          0
# 2     F00000004                      257          1          0
# 3     F00000005                      257          1          1
# 4     F00000006                      342          1          0
# ...         ...                      ...        ...        ...
# 4594  F00008078                     2138          0          1
# 4595  F00008079                     2139          0          1
# 4596  F00008080                     2267          0          1
# 4597  F00008082                     2267          0          1
# 4598  F00008083                     2267          0          1
#
#       Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# 0                          1                  0                0.0
# 1                          1                  0                0.0
# ...
